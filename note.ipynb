# %%
import db.database

# %%
db = db.database.get_database()

# %%
from datetime import datetime
from datastructure.constant import Exchange

# %%
db.load_tick_data('rb2310', Exchange('SHFE'), datetime(2023, 1,3), datetime(2023, 1,4))
# Out:
# [TickData(symbol='rb2310', exchange=<Exchange.SHFE: 'SHFE'>, datetime=Timestamp('2023-01-03 09:00:00.500001'), volume=25, turnover=1019070.0, open_interest=282210, last_price=4075.0, highest_price=4077.0, lowest_price=4070.0, bid_price_1=4070.0, ask_price_1=4075.0, bid_volume_1=3, ask_volume_1=5),
#  TickData(symbol='rb2310', exchange=<Exchange.SHFE: 'SHFE'>, datetime=Timestamp('2023-01-03 09:00:01'), volume=34, turnover=1385510.0, open_interest=282207, last_price=4070.0, highest_price=4077.0, lowest_price=4069.0, bid_price_1=4069.0, ask_price_1=4074.0, bid_volume_1=4, ask_volume_1=5),
#  TickData(symbol='rb2310', exchange=<Exchange.SHFE: 'SHFE'>, datetime=Timestamp('2023-01-03 09:00:01.500000'), volume=51, turnover=2076660.0, open_interest=282216, last_price=4067.0, highest_price=4077.0, lowest_price=4062.0, bid_price_1=4062.0, ask_price_1=4067.0, bid_volume_1=1, ask_volume_1=1),
# ...
